# %%
# %matplotlib inline
import torch
from torch import nn
from torch.nn import functional as F
from PIL import Image
import matplotlib.pyplot as plt
from pathlib import Path
import utils
import torchvision
from torchvision.io import image
from torchvision.transforms.functional import to_pil_image
import pandas as pd
import time
import numpy as np
import collections
import re
import random
import math

# %%
batch_size, num_steps = 32, 35
# train_iter, vocab = utils.load_data_txt(utils.sanguo_txt_path, batch_size, num_steps)
train_iter, vocab = utils.load_data_txt(utils.santi_txt_path, batch_size, num_steps)
print(len(vocab))
# Out:
# 1464

# %%
def get_lstm_params(vocab_size, num_hiddens, device):
    num_inputs = num_outputs = vocab_size

    def normal(shape):
        return torch.randn(size=shape, device=device)*0.01

    def init_three_params():
        return (normal((num_inputs, num_hiddens)), normal((num_hiddens, num_hiddens)), torch.zeros(num_hiddens, device=device))

    W_xi, W_hi, b_i = init_three_params()  # 输入门参数
    W_xf, W_hf, b_f = init_three_params()  # 遗忘门参数
    W_xo, W_ho, b_o = init_three_params()  # 输出门参数
    W_xc, W_hc, b_c = init_three_params()  # 候选记忆元参数
    # 输出层参数
    W_hq = normal((num_hiddens, num_outputs))
    b_q = torch.zeros(num_outputs, device=device)
    # 附加梯度
    params = [W_xi, W_hi, b_i, W_xf, W_hf, b_f, W_xo, W_ho, b_o, W_xc, W_hc, b_c, W_hq, b_q]
    for param in params:
        param.requires_grad_(True)
    return params

# %%
# 初始化状态（隐状态+候选记忆元）
def init_lstm_state(batch_size, num_hiddens, device):
    return (torch.zeros((batch_size, num_hiddens), device=device), torch.zeros((batch_size, num_hiddens), device=device))

# %%
# 定义模型
def lstm(inputs, state, params):
    [W_xi, W_hi, b_i, W_xf, W_hf, b_f, W_xo, W_ho, b_o, W_xc, W_hc, b_c, W_hq, b_q] = params
    (H, C) = state
    outputs = []
    for X in inputs:
        I = torch.sigmoid((X @ W_xi) + (H @ W_hi) + b_i)
        F = torch.sigmoid((X @ W_xf) + (H @ W_hf) + b_f)
        O = torch.sigmoid((X @ W_xo) + (H @ W_ho) + b_o)
        C_tilda = torch.tanh((X @ W_xc) + (H @ W_hc) + b_c)
        C = F * C + I * C_tilda
        H = O * torch.tanh(C)
        Y = (H @ W_hq) + b_q
        outputs.append(Y)
    return torch.cat(outputs, dim=0), (H, C)

# %%
# predict_prefix = ['cao cao', 'kingdom']
predict_prefix = ['三体组织', '物理学']

# %%
vocab_size, num_hiddens, device = len(vocab), 256, utils.try_gpu()
num_epochs, lr = 500, 1
model = utils.RNNModelScratch(len(vocab), num_hiddens, device, get_lstm_params, init_lstm_state, lstm)
utils.train_ch8(model, train_iter, vocab, lr, num_epochs, device, predict_prefix=predict_prefix)
# Out:
# 三体组织的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# epoch: 50/500, ppl: 484.24730154413913
# 三体组织，，，的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# epoch: 100/500, ppl: 482.5993570773085
# 三体组织，，的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# epoch: 150/500, ppl: 475.03783388234984
# 三体组织，，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的的，，的的
# epoch: 200/500, ppl: 461.7112383994697
# 三体组织，我是的，这，我的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，这，我是的的，
# epoch: 250/500, ppl: 422.3210795588473
# 三体组织，但是是个的，他是是个的，但是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他是是个的，他
# epoch: 300/500, ppl: 344.795105700851
# 三体组织，但是的个个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一个的，但是是一个，我是是一
# epoch: 350/500, ppl: 260.9811954462428
# 三体组织，他们的一个，他们是是一个，我们是，我们的，我是是的，你的，我们的，你是的，我们了的，你是，我们的，我们的，我们了了，你有了的，你是在的，你是，我们的，我们的，我们了了，你有了的，你是，我们的，我们的，我们了的，你有了，我们的，我们的，我们了的，你有了，我们的，我们的，我们了的，你有了，我们的，我们的，我们了的，你有了，我们的，我们的，我们了的，你有了，我们的，我们的，我们了的，你有了，我们的，我
# epoch: 400/500, ppl: 190.96086649475012
# 三体组织，他们这个一个，但是是一个半的，他们有了，我们是一个舰的，他们是这个中的是么，我们在这个度的是么的，但至了，我们也了了我们的理术。”“我们，你只在选择的是我们的，但有了这人。这人自的速航。”“我们在你的择’中是一个发的，因为在在在人的是动的，但为这个战的可次的，但为这个速的可么。”“我们在，你们在能了，我们自了选自了这个己的，但人了这个速的，我们在这个速的可么。”“我们，你只在能能的是我们的，我们
# epoch: 450/500, ppl: 110.90383379456075
# 三体组织，他们有一个一个个层的，但至是一个半中，在是帮了也次中中都次的，甚至在我们，就是以次的战术中上，我们现现了可次的理理战战，也为现现度度中在在都的学术术子的算算。”“是么想思的思分分是在定了，我们了不有，我们将在知到的理动的理子的研术，甚至在可能来来的理学学战战子的计算机。”“这么想思的想分分是一个失的。”“我们，你自能能有能能到到到到的，人现了不现的理理。”“我们在在在在在是是一个分子的人人。”“
# epoch: 500/500, ppl: 58.10202670318202
# 困惑度 58.1, 14029.2 词元/秒 cuda:0
# 三体组织，他们有一个一个个层的，但至是一个半中，在是帮了也次中中都次的，甚至在我们，就是以次的战术中上，我们现现了可次的理理战战，也为现现度度中在在都的学术术子的算算。”“是么想思的思分分是在定了，我们了不有，我们将在知到的理动的理子的研术，甚至在可能来来的理学学战战子的计算机。”“这么想思的想分分是一个失的。”“我们，你自能能有能能到到到到的，人现了不现的理理。”“我们在在在在在是是一个分子的人人。”“
# 物理学，他们这个一个，更是一个白中，这个是不样的是动的，甚至在现度，你帮是以次中！我次是我现。”“是是限现舰号号击是是一个舰的，而现在任度度号在在在，我们还有了可见的理子的理术。”“我在在在在想分的是是是一个信的，你们我们，不能能能能到的理术，但可能能能的可次的学子，但次现现度，每是在自战战术都都战到的人术。”“你在想自在想分的是责失的失子的技术。”“你你你自思思钢印印吗？”“我们是有有择’，我自然选择

# %% [markdown]
# # 简洁实现

# %%
num_inputs = vocab_size
lstm_layer = nn.LSTM(num_inputs, num_hiddens)
model = utils.RNNModel(lstm_layer, len(vocab))
model = model.to(device)
utils.train_ch8(model, train_iter, vocab, lr, num_epochs, device, predict_prefix=predict_prefix)
# Out:
# 三体组织的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的的
# epoch: 50/500, ppl: 484.3971834472492
# 三体组织，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# epoch: 100/500, ppl: 468.0195082052079
# 三体组织的，，我，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，
# epoch: 150/500, ppl: 407.5926265892861
# 三体组织，但是个，这的，，是是，这的，，是在的，，我们的，，是是，，我的，，我们的，，是是，，我的，，我们的，，是是，，不的，，是在，，我的，，我的，，我们的，，是是，，不的，，比的，，我们的，，是是，，不的，，是在，，我的，，我的，，我的，，我们的，，是是，，不的，，比的，，我们的，，是是，，我的，，我是，，我的，，是，这个，，是是，，我的，，我的，，我们的，，是是，，不的，，比的，，我们的，，是是，，
# epoch: 200/500, ppl: 305.58618952588273
# 三体组织的，他们的一个的，但是是一个择的，我是在有了。”“我是一个择’号，我有有有的人。”“我是一个择号的，我是在有了。”“我是一个择’号，我有有有的人。”“我是一个择号的，我是在有了。”“我是一个择’号，我有有有的人。”“我是一个择号的，我是在有了。”“我是一个择’号，我有有有的人。”“我是一个择号的，我是在有了。”“我是一个择’号，我有有有的人。”“我是一个择号的，我是在有了。”“我是一个择’号，我有
# epoch: 250/500, ppl: 204.094185539138
# 三体组织的地动，他们在一个光的，他们是一个择号，我是是一个舰的，他们是一个，我们是一个层号，我是在在舰的，我是是一个生号，我是在在舰的，我是是一个生的，他是在不了，我们是一个！号号我是不个。”“我是一个，你们在外了，我们我们了。”“我是是个个’号，我是在在舰的。”“我是这个种’号，我是在有了。”“我是这个个’号，我是在在舰的。”“我是这个种’号，我是在有了。”“我是这个个’号，我是在在速的，我们是一个’号
# epoch: 300/500, ppl: 111.026113929069
# 三体组织有，这些的是星星，他们在一个光的光光，也是一个舰的传中，但想在不有的光能，我是一个远的可能中，我是一个舰的可能，他只在不同的技术，我是我们了不有了，这人一个舰的可能，不是我们不不了。”“我是是一个能能能，我们有有了。但是是一个战术的可能的行星的，你是一个战的。”“但为是一个能能中，我们在有了。”“我自然选择’号的航航，也有在有了。”“我是这个种能能能，我们我们有了技术。”“是是是能能能能的，因有有
# epoch: 350/500, ppl: 50.44561447606753
# 三体组织1　，这些类的一天，他们在一半的大子的一次金子了一，他次重的，能懂在的指球中已已次的空空，但像像像，真次将忙的指技已已经想的，因且来的一次，以次在不了了了么么都想的，因且现在一个次次的一子子发—什么。在果他们的研究是一个战量的，正将将，我们说自自己系的一面发发，因为很很很果，你的物理中已已么么子行星的人星。”。”三体子？？？”，她是类类战位，他们到到到一个看子的十空的，甚至自自选择’号的一种计算，
# epoch: 400/500, ppl: 20.043229703616195
# 三体组织16.　三体、机36.　三体、远31.　三体、三体、、宇宙、.　、三日22.　三体、三12.　红岸之22.　三体、三日、、·、、球、、死26.　三体、三11.　三体、三日、··、、球、、三日.　三体、三体12.　红岸之22.　三体、三日、、·、、摆、、大日2.　三体、三12.　三体、三日、、·、、球、、三日、三日.　三体、122.　红岸之12.　三体、爱因斯、、·、、大、、三日、三日6.　三体、1
# epoch: 450/500, ppl: 9.404694976328084
# 三体组织　在星的学星。他们等等，你分出现了恒恒星的周现：够了一条螺旋的，动质的工度，即好是个种白的光流流的发句。”，那块的光吨的石头，能能析析度的可低。但想，您有现来的研究，是是还有很号的人人：念术，您且现来d长各以任事的技术，我么了很次讲来的基学中战较了一次应巨果曾都都么的两天，从管了一直射来的荣测中果，我更取我们以以实，这是这种大大的低人子子什么子。”“你们，您时估了什定的低技技好，因为你来的研究出出
# epoch: 500/500, ppl: 4.575654768834056
# 困惑度 4.6, 113379.1 词元/秒 cuda:0
# 三体组织　在星的学星。他们等等，你分出现了恒恒星的周现：够了一条螺旋的，动质的工度，即好是个种白的光流流的发句。”，那块的光吨的石头，能能析析度的可低。但想，您有现来的研究，是是还有很号的人人：念术，您且现来d长各以任事的技术，我么了很次讲来的基学中战较了一次应巨果曾都都么的两天，从管了一直射来的荣测中果，我更取我们以以实，这是这种大大的低人子子什么子。”“你们，您时估了什定的低技技好，因为你来的研究出出
# 物理学，他至星世上纪至，与疯子相上的可限化化不不的；重，不有像像过不可以玩像的心心，他们去就对对高的荣孩。这次的金来的研究的战力，我们，他们说，但人敬的战术还没有的三体。”，像瞳您着思想钢千，人人类而度的可可。”“我您，您坚坚速，这次次次吧到自己都都想的信度的研究。”经所在？？想子原和，因用的事度，我人到也射射看还没有的含航上，怕面面面永的千幻的，计子计算度大的低儿子战念，您且解来dc来常任任的两术，我

# %% [markdown]
# # 长短期记忆网络有三种类型的门：输入门、遗忘门和输出门。
#
# # 长短期记忆网络的隐藏层输出包括“隐状态”和“记忆元”。只有隐状态会传递到输出层，而记忆元完全属于内部信息。
#
# # 长短期记忆网络可以缓解梯度消失和梯度爆炸。
